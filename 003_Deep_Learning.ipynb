# %% [markdown]
# <center><h1>Microstucture and Trading Systems</h1></center>
#
# <center><h1>003 Deep Learning Project</h1></center>
#
# <img src="Logo-ITESO.png" alt="Logo" width="500" style="display: block; margin: auto;">
#
# <center><h3>Alejandra Flores Arias</h3></center>
#
# <center><h3>Juan Pablo Guzmán Aceves</h3></center>

# %% [markdown]
# # Description
#
# Create an algorithmic trading strategy optimizing the following hyperparameters with at least 50 trials:
#
# - Stop Loss / Take Profit
# - Number of shares per trade
# - 3 Technical Indicators (Use the technical indicators to generate trading signals)
# - Calculate the following metrics of the trading strategy (Sharpe, Sortino, Calmar ratios and Win/Loss percentage)

# %%
# Import librarys
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import optuna
import ta

# %%
data = pd.read_csv("aapl_5m_train.csv").dropna()
data.head()
# Out:
#    Unnamed: 0   Timestamp  Gmtoffset             Datetime        Open  \
# 0           0  1609770600          0  2021-01-04 14:30:00  133.570007
# 1           1  1609770900          0  2021-01-04 14:35:00  132.750000
# 2           2  1609771200          0  2021-01-04 14:40:00  131.500000
# 3           3  1609771500          0  2021-01-04 14:45:00  132.000000
# 4           4  1609771800          0  2021-01-04 14:50:00  132.000000
#
#          High         Low       Close     Volume
# 0  133.611602  132.389999  132.809997  6624663.0
# 1  132.750000  131.809997  131.889999  2541553.0
# 2  132.339996  131.500000  132.059997  2492415.0
# 3  132.250000  131.899993  132.250000  1859131.0
# 4  132.018096  131.520004  131.589996  1780105.0

# %% [markdown]
# # Description of Indicators
#
# ### **RSI (Relative Strength Index)**
#
# The RSI is a momentum indicator that measures the speed and magnitude of price changes in an asset. It operates as an oscillator on a scale from 0 to 100, helping to identify overbought (>70) and oversold (<30) conditions. This makes it useful for spotting potential trend reversals and optimizing market entry or exit points.
#
# ### **Bollinger Bands**
#
# Bollinger Bands consist of a central moving average and two outer bands set at a certain standard deviation, forming a volatility channel. When the bands expand, they indicate high volatility, whereas contractions suggest market consolidation. These bands are commonly used to assess the risk of sudden price movements and to detect trend breakouts.
#
# ### **EMA (Exponential Moving Average)**
#
# The EMA is a moving average that assigns greater weight to recent data, making it more responsive to trend changes. It helps smooth out price fluctuations and determines the trend direction, often acting as dynamic support or resistance. The EMA plays a crucial role in algorithmic trading strategies and quantitative models.

# %%
rsi = ta.momentum.RSIIndicator(data.Close, window=25)
bb = ta.volatility.BollingerBands(data.Close, window=16, window_dev=2) 
ema = ta.trend.EMAIndicator(data.Close, window=30)

# %% [markdown]
# # Creating "Buy" and "Sell" signals

# %%
dataset = data.copy()
dataset["RSI"] = rsi.rsi()
dataset["BB"] = bb.bollinger_mavg()
dataset["EMA"] = ema.ema_indicator()

dataset["RSI_BUY"] = dataset["RSI"] < 25
dataset["RSI_SELL"] = dataset["RSI"] > 75

dataset["BB_BUY"] = bb.bollinger_lband_indicator().astype(bool) # lower band
dataset["BB_SELL"] = bb.bollinger_hband_indicator().astype(bool) # higher band

dataset["EMA_BUY"] = dataset["Close"] > dataset["EMA"]  
dataset["EMA_SELL"] = dataset["Close"] < dataset["EMA"]

dataset = dataset.dropna()
dataset.head()
# Out:
#     Unnamed: 0   Timestamp  Gmtoffset             Datetime        Open  \
# 29          29  1609779300          0  2021-01-04 16:55:00  129.130004
# 30          30  1609779600          0  2021-01-04 17:00:00  128.809997
# 31          31  1609779900          0  2021-01-04 17:05:00  128.596694
# 32          32  1609780200          0  2021-01-04 17:10:00  128.233398
# 33          33  1609780500          0  2021-01-04 17:15:00  127.410003
#
#           High         Low       Close     Volume        RSI          BB  \
# 29  129.179992  128.789993  128.820007  2439704.0  24.492226  130.022481
# 30  128.919296  128.399993  128.580001  2340696.0  23.230851  129.868418
# 31  128.770004  128.330001  128.351699  1508454.0  22.102922  129.718531
# 32  128.249893  127.400100  127.410003  4419879.0  18.287804  129.512294
# 33  128.029998  126.760002  128.005004  2891333.0  26.623658  129.325107
#
#            EMA  RSI_BUY  RSI_SELL  BB_BUY  BB_SELL  EMA_BUY  EMA_SELL
# 29  130.534815     True     False   False    False    False      True
# 30  130.408698     True     False   False    False    False      True
# 31  130.275989     True     False   False    False    False      True
# 32  130.091086     True     False    True    False    False      True
# 33  129.956500    False     False   False    False    False      True

# %% [markdown]
# # Strategy with long and short positions using the three indicators choseen

# %%
capital = 1000000
com = 0.125 / 100  # Comisión de compra/venta
n_shares = 1000  # Número de acciones por operación

portfolio_value = [capital]

stop_loss = 0.15  # Stop Loss del 15%
take_profit = 0.08  # Take Profit del 8%

win = 0
losses = 0

active_long_positions = None  # Solo una posición activa de cada tipo
active_short_positions = None

for i, row in dataset.iterrows():
    # === Cerrar posiciones largas (Long) ===
    if active_long_positions:
        # Cierre por Stop Loss
        if row.Close < active_long_positions["stop_loss"]:
            pnl = row.Close * n_shares * (1 - com)
            capital += pnl
            active_long_positions = None
            losses += 1

        # Cierre por Take Profit
        elif row.Close > active_long_positions["take_profit"]:
            pnl = row.Close * n_shares * (1 - com)
            capital += pnl
            active_long_positions = None
            win += 1

    # === Cerrar posiciones cortas (Short) ===
    if active_short_positions:
        # Cierre por Stop Loss
        if row.Close > active_short_positions["stop_loss"]:
            pnl = (active_short_positions["opened_at"] - row.Close) * n_shares * (1 - com)
            capital += pnl
            active_short_positions = None
            losses += 1

        # Cierre por Take Profit
        elif row.Close < active_short_positions["take_profit"]:
            pnl = (active_short_positions["opened_at"] - row.Close) * n_shares * (1 - com)
            capital += pnl
            active_short_positions = None
            win += 1

    # === Abrir posiciones largas (Long) ===
    if (row.RSI_BUY + row.BB_BUY + row.EMA_BUY) >= 2 and active_long_positions is None:
        cost = row.Close * n_shares * (1 + com)
        if capital >= cost:  # Solo abrir si hay capital suficiente
            capital -= cost
            active_long_positions = {
                "datetime": row.Datetime,
                "opened_at": row.Close,
                "take_profit": row.Close * (1 + take_profit),
                "stop_loss": row.Close * (1 - stop_loss),
            }

    # === Abrir posiciones cortas (Short) ===
    if (row.RSI_SELL + row.BB_SELL + row.EMA_SELL) >= 2 and active_short_positions is None:
        credit = row.Close * n_shares * (com)
        if capital >= credit:  # Solo abrir si hay capital suficiente
            capital -= credit  
            active_short_positions = {
                "datetime": row.Datetime,
                "opened_at": row.Close,
                "take_profit": row.Close * (1 - take_profit),
                "stop_loss": row.Close * (1 + stop_loss),
            }

    # === Calcular el valor del portafolio ===
    long_value = row.Close * n_shares if active_long_positions else 0
    short_value = (active_short_positions["opened_at"] - row.Close) * n_shares if active_short_positions else 0

    # Agregar el valor total del portafolio
    portfolio_value.append(capital + long_value + short_value)

# %% [markdown]
# # Portfolio Value vs Stock Price Plot

# %%
fig, ax = plt.subplots(1, 1, figsize=(12,6))

ax.plot(portfolio_value,label = "Porfolio Value")
ax.legend()
ax2 = ax.twinx()
ax2.plot(data.Close, c="C1")
plt.title("Portfolio Value vs Stock Price")

plt.show()

# %%
len(dataset)
# Out:
# 39131

# %% [markdown]
# # Description of Ratios
#
# ### **Sharpe Ratio**
#
# The Sharpe Ratio measures the risk-adjusted return of an investment by comparing its excess return (over the risk-free rate) to its volatility. A higher Sharpe Ratio indicates better risk-adjusted performance, making it useful for evaluating investment strategies and portfolio optimization.
#
# $$Sharpe\ Ratio = \frac{\sqrt{N} \times (E(R_x) - R_f)}{\sigma_x}$$
#
#
# Where:
# - $( N )$ = Number of periods (e.g., trading days in a year).
# - $( E(R_x) )$ = Expected return of the asset.
# - $( R_f )$ = Risk-free rate.
# - $( \sigma_x )$ = Standard deviation of returns (volatility).
#
#
# ### **Sortino Ratio**
#
# The Sortino Ratio is a refinement of the Sharpe Ratio that focuses only on downside risk. It measures excess return relative to the standard deviation of negative returns, providing a clearer picture of risk-adjusted performance by ignoring upside volatility. This makes it ideal for assessing investments where minimizing losses is a priority.
#
# $$Sortino\ Ratio = \frac{E(R_x) - R_f}{\sigma_d}$$
#
# Where:
# - $( E(R_x) )$ = Expected return of the asset.
# - $( R_f )$ = Risk-free rate.
# - $( \sigma_d )$ = Standard deviation of negative returns (downside risk).
#
#
# ### **Calmar Ratio**
#
# The Calmar Ratio evaluates an investment’s risk-adjusted return by comparing its annualized return to the maximum drawdown. A higher Calmar Ratio suggests better performance with lower downside risk, making it valuable for assessing long-term portfolio stability, particularly in high-volatility markets.
#
# $$Calmar\ Ratio = \frac{R_{annualized}}{Max\ Drawdown}$$
#
# Where:
# - $( R_{annualized} )$ = Annualized return of the investment.
# - $( Max\ Drawdown )$ = Largest peak-to-trough decline in portfolio value.
#
#
# ### **Win/Loss Percentage**
#
# The Win/Loss Percentage calculates the proportion of profitable trades relative to total trades. It helps traders gauge the consistency of a strategy by measuring the frequency of winning trades. While useful, it should be analyzed alongside other risk metrics, as a high win percentage does not always indicate overall profitability.
#
# $$Win/Loss\ Percentage = \left( \frac{W}{W + L} \right) \times 100$$
#
# Where:
# - $( W )$ = Number of winning trades.
# - $( L )$ = Number of losing trades.

# %%
rf = 0
N = 252*78

# Sharpe

def sharpe_ratio(portfolio_val, rf,N):
    ds = pd.Series(portfolio_val)
    returns = ds.pct_change().dropna() 
    mean = returns.mean() # *N
    std = returns.std() # * np.sqrt(N)
    if std == 0:
        return 0

    sharpe_ratio = np.sqrt(N)*(mean/std)

    return sharpe_ratio

#sharpe = sharpe_ratio(dataset, rf,N)
#print(f"Ratio de Sharpe: {sharpe:.4f}")

# Sortino

def sortino_ratio(portfolio_val, N, rf):
    returns = pd.Series(portfolio_val).pct_change().dropna()
    mean_excess_return = (returns.mean() - rf) * N  
    downside_std = returns[returns < 0].std() * np.sqrt(N)

    # Evitar división por cero
    if downside_std == 0:
        return np.nan  

    sortino = mean_excess_return / downside_std

    return sortino

#sortino = sortino_ratio(dataset,N,rf)
#print(f"Ratio de Sortino: {sortino:.4f}")


# Calmar

def calmar_ratio(portfolio_val, N, rf):
    returns = pd.Series(portfolio_val).pct_change().dropna()
    annualized_return = (returns.mean() - rf) * N

    
    cumulative_returns = (1 + returns).cumprod()  # Crecimiento del portafolio
    peak = cumulative_returns.cummax()  # Picos históricos
    dd = (cumulative_returns / peak) - 1  # Drawdown en cada punto
    max_dd = dd.min()  # Máximo drawdown registrado

    if max_dd == 0:
        return np.nan  

    calmar_ratio = annualized_return / abs(max_dd)

    return calmar_ratio

#calmar = calmar_ratio(dataset, N, rf)
#print(f"Ratio de Calmar: {calmar:.4f}")

# Win/Loss

def win_loss_percentage(portfolio_val):
    returns = pd.Series(portfolio_val).pct_change().dropna()
    wins = (returns > 0).sum()  # Retornos positivos
    total_trades = len(returns)  # Total de operaciones

    if total_trades == 0:
        return np.nan  

    win_loss_ratio = (wins / total_trades) * 100

    return win_loss_ratio

#win_loss = win_loss_percentage(dataset)
#print(f"Win/Loss Percentage: {win_loss:.2f}%")

# %%
def objective_func(trial, data):
    rsi_window = trial.suggest_int("rsi_window",10,100)
    rsi_lower = trial.suggest_int("rsi_lower",10,25)
    rsi_upper = trial.suggest_int("rsi_upper",70,95)

    stop_loss = trial.suggest_float("stop_loss",0.01,0.1)
    take_profit = trial.suggest_float("take_profit",0.05,0.2)
    n_shares = trial.suggest_categorical("n_shares",[1000,2000,4000,5000])
    
    bb_window= trial.suggest_int("bb_window",5,100)
    bb_window_dev= trial.suggest_int("bb_window_dev",1,3)
    ema_window= trial.suggest_int("ema_window",10,55)

    
    rsi = ta.momentum.RSIIndicator(data.Close, window=rsi_window)
    bb = ta.volatility.BollingerBands(data.Close, window=bb_window, window_dev=bb_window_dev) # dos desviaciones estandar
    ema = ta.trend.EMAIndicator(data.Close, window=ema_window)
    dataset = data.copy()
    dataset["RSI"] = rsi.rsi()
    dataset["BB"] = bb.bollinger_mavg()
    dataset["EMA"] = ema.ema_indicator()
    
    dataset["RSI_BUY"] = dataset["RSI"] < rsi_lower
    dataset["RSI_SELL"] = dataset["RSI"] > rsi_upper
    
    dataset["BB_BUY"] = bb.bollinger_lband_indicator().astype(bool) # lower band
    dataset["BB_SELL"] = bb.bollinger_hband_indicator().astype(bool) # higher band
    
    dataset["EMA_BUY"] = dataset["Close"] > dataset["EMA"]  
    dataset["EMA_SELL"] = dataset["Close"] < dataset["EMA"]

    dataset = dataset.dropna()
    capital = 1000000
    com = 0.125/100
    
    
    portfolio_value = [capital]
    
    
    
    win = 0
    losses = 0

    active_long_positions = None # una sola posicion activa de cada tipo
    active_short_positions = None
    
    for i, row in dataset.iterrows():
        # === Cerrar posiciones largas (Long) ===
        if active_long_positions:
            # Cierre por Stop Loss
            if row.Close < active_long_positions["stop_loss"]:
                pnl = row.Close * n_shares * (1 - com)
                capital += pnl
                active_long_positions = None
                losses += 1
    
            # Cierre por Take Profit
            elif row.Close > active_long_positions["take_profit"]:
                pnl = row.Close * n_shares * (1 - com)
                capital += pnl
                active_long_positions = None
                win += 1
    
        # === Cerrar posiciones cortas (Short) ===
        if active_short_positions:
            # Cierre por Stop Loss
            if row.Close > active_short_positions["stop_loss"]:
                pnl = (active_short_positions["opened_at"] - row.Close) * n_shares * (1 - com)
                capital += pnl
                active_short_positions = None
                losses += 1
    
            # Cierre por Take Profit
            elif row.Close < active_short_positions["take_profit"]:
                pnl = (active_short_positions["opened_at"] - row.Close) * n_shares * (1 - com)
                capital += pnl
                active_short_positions = None
                win += 1
    
        # === Abrir posiciones largas (Long) ===
        if (row.RSI_BUY + row.BB_BUY + row.EMA_BUY) >= 2 and active_long_positions is None:
            cost = row.Close * n_shares * (1 + com)
            if capital >= cost:  # Solo abrir si hay capital suficiente
                capital -= cost
                active_long_positions = {
                    "datetime": row.Datetime,
                    "opened_at": row.Close,
                    "take_profit": row.Close * (1 + take_profit),
                    "stop_loss": row.Close * (1 - stop_loss),
                }
    
        # === Abrir posiciones cortas (Short) ===
        if (row.RSI_SELL + row.BB_SELL + row.EMA_SELL) >= 2 and active_short_positions is None:
            credit = row.Close * n_shares * (com)
            if capital >= credit:  # Solo abrir si hay capital suficiente
                capital -= credit  
                active_short_positions = {
                    "datetime": row.Datetime,
                    "opened_at": row.Close,
                    "take_profit": row.Close * (1 - take_profit),
                    "stop_loss": row.Close * (1 + stop_loss),
                }
    
        # === Calcular el valor del portafolio ===
        long_value = row.Close * n_shares if active_long_positions else 0
        short_value = (active_short_positions["opened_at"] - row.Close) * n_shares if active_short_positions else 0
    
        # Agregar el valor total del portafolio
        portfolio_value.append(capital + long_value + short_value)
        returns = np.diff(portfolio_value) / portfolio_value[:-1]

    sharpe = sharpe_ratio(portfolio_value,rf,N)
    sortino = sortino_ratio(portfolio_value,N,rf)
    calmar = calmar_ratio(portfolio_value, N, rf)
    win_loss = win_loss_percentage(portfolio_value)

    return sharpe

# %%
study = optuna.create_study(direction="maximize") # que quiero, miniimizar o maximizar
study.optimize(lambda x: objective_func(x,data), n_trials=50)
# Out:
# [I 2025-03-27 21:14:16,659] A new study created in memory with name: no-name-2934a7a4-2384-40d0-bb59-9c6d6f6e35ab
# [I 2025-03-27 21:17:02,468] Trial 0 finished with value: 0.7372138248289035 and parameters: {'rsi_window': 20, 'rsi_lower': 12, 'rsi_upper': 71, 'stop_loss': 0.09084313438933406, 'take_profit': 0.06981123644177901, 'n_shares': 1000, 'bb_window': 47, 'bb_window_dev': 1, 'ema_window': 43}. Best is trial 0 with value: 0.7372138248289035.
# [I 2025-03-27 21:20:18,686] Trial 1 finished with value: -0.7629996478859389 and parameters: {'rsi_window': 37, 'rsi_lower': 15, 'rsi_upper': 82, 'stop_loss': 0.044697474053115596, 'take_profit': 0.07008748783095166, 'n_shares': 4000, 'bb_window': 55, 'bb_window_dev': 3, 'ema_window': 47}. Best is trial 0 with value: 0.7372138248289035.
# [I 2025-03-27 21:23:09,697] Trial 2 finished with value: 0.4581352221095825 and parameters: {'rsi_window': 91, 'rsi_lower': 16, 'rsi_upper': 71, 'stop_loss': 0.09070146343953965, 'take_profit': 0.16700323993155614, 'n_shares': 2000, 'bb_window': 25, 'bb_window_dev': 3, 'ema_window': 48}. Best is trial 0 with value: 0.7372138248289035.
# [I 2025-03-27 21:26:14,225] Trial 3 finished with value: 0.9081386477558485 and parameters: {'rsi_window': 42, 'rsi_lower': 21, 'rsi_upper': 92, 'stop_loss': 0.04792420531034849, 'take_profit': 0.11198750728135448, 'n_shares': 4000, 'bb_window': 91, 'bb_window_dev': 1, 'ema_window': 40}. Best is trial 3 with value: 0.9081386477558485.
# [I 2025-03-27 21:29:00,743] Trial 4 finished with value: 0.08968253305882407 and parameters: {'rsi_window': 52, 'rsi_lower': 18, 'rsi_upper': 70, 'stop_loss': 0.05495485566624972, 'take_profit': 0.14696812896136946, 'n_shares': 1000, 'bb_window': 19, 'bb_window_dev': 3, 'ema_window': 16}. Best is trial 3 with value: 0.9081386477558485.
# [I 2025-03-27 21:31:54,896] Trial 5 finished with value: 0.18409964671611465 and parameters: {'rsi_window': 34, 'rsi_lower': 19, 'rsi_upper': 95, 'stop_loss': 0.022203754302662193, 'take_profit': 0.14481433929326623, 'n_shares': 5000, 'bb_window': 31, 'bb_window_dev': 2, 'ema_window': 18}. Best is trial 3 with value: 0.9081386477558485.
# [I 2025-03-27 21:34:45,520] Trial 6 finished with value: -0.0037563555401687026 and parameters: {'rsi_window': 42, 'rsi_lower': 16, 'rsi_upper': 77, 'stop_loss': 0.0779457736522279, 'take_profit': 0.11333820876527505, 'n_shares': 4000, 'bb_window': 69, 'bb_window_dev': 1, 'ema_window': 31}. Best is trial 3 with value: 0.9081386477558485.
# [I 2025-03-27 21:38:02,235] Trial 7 finished with value: 0.0 and parameters: {'rsi_window': 63, 'rsi_lower': 16, 'rsi_upper': 84, 'stop_loss': 0.07428305318035339, 'take_profit': 0.08451626640146015, 'n_shares': 5000, 'bb_window': 25, 'bb_window_dev': 3, 'ema_window': 34}. Best is trial 3 with value: 0.9081386477558485.
# [I 2025-03-27 21:40:56,293] Trial 8 finished with value: 0.8284914438446893 and parameters: {'rsi_window': 46, 'rsi_lower': 21, 'rsi_upper': 85, 'stop_loss': 0.08163426682881313, 'take_profit': 0.053432835876643374, 'n_shares': 1000, 'bb_window': 78, 'bb_window_dev': 2, 'ema_window': 27}. Best is trial 3 with value: 0.9081386477558485.
# [I 2025-03-27 21:44:12,008] Trial 9 finished with value: 0.0 and parameters: {'rsi_window': 48, 'rsi_lower': 12, 'rsi_upper': 85, 'stop_loss': 0.0379780025703161, 'take_profit': 0.18626200485510136, 'n_shares': 2000, 'bb_window': 91, 'bb_window_dev': 2, 'ema_window': 18}. Best is trial 3 with value: 0.9081386477558485.
# [I 2025-03-27 21:47:10,058] Trial 10 finished with value: -1.5295805598453294 and parameters: {'rsi_window': 71, 'rsi_lower': 24, 'rsi_upper': 95, 'stop_loss': 0.011537495007785857, 'take_profit': 0.1093081166614679, 'n_shares': 4000, 'bb_window': 98, 'bb_window_dev': 1, 'ema_window': 38}. Best is trial 3 with value: 0.9081386477558485.
# [I 2025-03-27 21:49:57,065] Trial 11 finished with value: -0.6853259485680491 and parameters: {'rsi_window': 11, 'rsi_lower': 22, 'rsi_upper': 90, 'stop_loss': 0.06524355217290555, 'take_profit': 0.05098518782720708, 'n_shares': 1000, 'bb_window': 78, 'bb_window_dev': 2, 'ema_window': 27}. Best is trial 3 with value: 0.9081386477558485.
# [I 2025-03-27 21:53:27,398] Trial 12 finished with value: 0.9621710882069902 and parameters: {'rsi_window': 74, 'rsi_lower': 21, 'rsi_upper': 89, 'stop_loss': 0.038070366798408445, 'take_profit': 0.09560929474346382, 'n_shares': 4000, 'bb_window': 79, 'bb_window_dev': 1, 'ema_window': 55}. Best is trial 12 with value: 0.9621710882069902.
# [I 2025-03-27 21:56:49,785] Trial 13 finished with value: 0.0 and parameters: {'rsi_window': 79, 'rsi_lower': 25, 'rsi_upper': 90, 'stop_loss': 0.036087105143170484, 'take_profit': 0.09870373730652236, 'n_shares': 4000, 'bb_window': 85, 'bb_window_dev': 1, 'ema_window': 55}. Best is trial 12 with value: 0.9621710882069902.
# [I 2025-03-27 22:00:03,543] Trial 14 finished with value: 0.9890116348900878 and parameters: {'rsi_window': 97, 'rsi_lower': 21, 'rsi_upper': 90, 'stop_loss': 0.05331546174688905, 'take_profit': 0.13419751840453784, 'n_shares': 4000, 'bb_window': 64, 'bb_window_dev': 1, 'ema_window': 55}. Best is trial 14 with value: 0.9890116348900878.
# [I 2025-03-27 22:03:08,145] Trial 15 finished with value: 0.9801959512138178 and parameters: {'rsi_window': 99, 'rsi_lower': 23, 'rsi_upper': 88, 'stop_loss': 0.02534768285726662, 'take_profit': 0.13624606113039078, 'n_shares': 4000, 'bb_window': 60, 'bb_window_dev': 1, 'ema_window': 55}. Best is trial 14 with value: 0.9890116348900878.
# [I 2025-03-27 22:06:17,503] Trial 16 finished with value: 0.9588493027609768 and parameters: {'rsi_window': 100, 'rsi_lower': 23, 'rsi_upper': 80, 'stop_loss': 0.023360213053946824, 'take_profit': 0.13362940695057332, 'n_shares': 4000, 'bb_window': 56, 'bb_window_dev': 1, 'ema_window': 49}. Best is trial 14 with value: 0.9890116348900878.
# [I 2025-03-27 22:09:24,543] Trial 17 finished with value: 0.17953826248575716 and parameters: {'rsi_window': 87, 'rsi_lower': 19, 'rsi_upper': 88, 'stop_loss': 0.06617179191307979, 'take_profit': 0.16730707562585861, 'n_shares': 4000, 'bb_window': 40, 'bb_window_dev': 2, 'ema_window': 52}. Best is trial 14 with value: 0.9890116348900878.
# [I 2025-03-27 22:12:10,925] Trial 18 finished with value: -0.542883785943894 and parameters: {'rsi_window': 99, 'rsi_lower': 25, 'rsi_upper': 77, 'stop_loss': 0.01044120790031209, 'take_profit': 0.13136512297249378, 'n_shares': 2000, 'bb_window': 66, 'bb_window_dev': 1, 'ema_window': 11}. Best is trial 14 with value: 0.9890116348900878.
# [I 2025-03-27 22:15:36,161] Trial 19 finished with value: -1.3161973087203538 and parameters: {'rsi_window': 87, 'rsi_lower': 23, 'rsi_upper': 87, 'stop_loss': 0.02665411791306469, 'take_profit': 0.158337490166352, 'n_shares': 5000, 'bb_window': 65, 'bb_window_dev': 1, 'ema_window': 44}. Best is trial 14 with value: 0.9890116348900878.
# [I 2025-03-27 22:18:21,426] Trial 20 finished with value: -0.5006941570476994 and parameters: {'rsi_window': 68, 'rsi_lower': 20, 'rsi_upper': 92, 'stop_loss': 0.059774227065144535, 'take_profit': 0.19901693580352037, 'n_shares': 4000, 'bb_window': 10, 'bb_window_dev': 2, 'ema_window': 52}. Best is trial 14 with value: 0.9890116348900878.
# [I 2025-03-27 22:37:33,913] Trial 21 finished with value: 1.0475002909073587 and parameters: {'rsi_window': 75, 'rsi_lower': 22, 'rsi_upper': 88, 'stop_loss': 0.03182017731480323, 'take_profit': 0.09484430613647962, 'n_shares': 4000, 'bb_window': 74, 'bb_window_dev': 1, 'ema_window': 55}. Best is trial 21 with value: 1.0475002909073587.
# [I 2025-03-27 22:40:34,621] Trial 22 finished with value: 0.9400138385730371 and parameters: {'rsi_window': 83, 'rsi_lower': 23, 'rsi_upper': 93, 'stop_loss': 0.029716659867178155, 'take_profit': 0.12434377091209547, 'n_shares': 4000, 'bb_window': 61, 'bb_window_dev': 1, 'ema_window': 55}. Best is trial 21 with value: 1.0475002909073587.
# [I 2025-03-27 22:43:16,441] Trial 23 finished with value: 0.7455467537540943 and parameters: {'rsi_window': 60, 'rsi_lower': 10, 'rsi_upper': 86, 'stop_loss': 0.0182806275625685, 'take_profit': 0.13766258183033625, 'n_shares': 4000, 'bb_window': 48, 'bb_window_dev': 1, 'ema_window': 50}. Best is trial 21 with value: 1.0475002909073587.
# [I 2025-03-27 22:46:31,666] Trial 24 finished with value: 0.0 and parameters: {'rsi_window': 95, 'rsi_lower': 22, 'rsi_upper': 82, 'stop_loss': 0.048254172395563184, 'take_profit': 0.11870062428769326, 'n_shares': 4000, 'bb_window': 71, 'bb_window_dev': 1, 'ema_window': 45}. Best is trial 21 with value: 1.0475002909073587.
# [I 2025-03-27 22:49:43,214] Trial 25 finished with value: 0.9033368975720488 and parameters: {'rsi_window': 78, 'rsi_lower': 20, 'rsi_upper': 88, 'stop_loss': 0.032669778597248046, 'take_profit': 0.09692493168706146, 'n_shares': 4000, 'bb_window': 44, 'bb_window_dev': 1, 'ema_window': 40}. Best is trial 21 with value: 1.0475002909073587.
# [I 2025-03-27 22:53:19,304] Trial 26 finished with value: -0.329273115150966 and parameters: {'rsi_window': 92, 'rsi_lower': 24, 'rsi_upper': 91, 'stop_loss': 0.04368972078897838, 'take_profit': 0.15942758563584716, 'n_shares': 4000, 'bb_window': 59, 'bb_window_dev': 2, 'ema_window': 52}. Best is trial 21 with value: 1.0475002909073587.
# [I 2025-03-27 22:56:33,544] Trial 27 finished with value: 0.0 and parameters: {'rsi_window': 85, 'rsi_lower': 18, 'rsi_upper': 93, 'stop_loss': 0.01771991619001594, 'take_profit': 0.08445338340985883, 'n_shares': 5000, 'bb_window': 73, 'bb_window_dev': 1, 'ema_window': 51}. Best is trial 21 with value: 1.0475002909073587.
# [I 2025-03-27 22:59:18,633] Trial 28 finished with value: -0.7480950213589728 and parameters: {'rsi_window': 79, 'rsi_lower': 22, 'rsi_upper': 80, 'stop_loss': 0.058870358448135554, 'take_profit': 0.14809351735898985, 'n_shares': 4000, 'bb_window': 37, 'bb_window_dev': 1, 'ema_window': 46}. Best is trial 21 with value: 1.0475002909073587.
# [I 2025-03-27 23:02:15,984] Trial 29 finished with value: 0.5964900559370759 and parameters: {'rsi_window': 96, 'rsi_lower': 24, 'rsi_upper': 88, 'stop_loss': 0.029779669661095777, 'take_profit': 0.07460056959654837, 'n_shares': 2000, 'bb_window': 47, 'bb_window_dev': 1, 'ema_window': 42}. Best is trial 21 with value: 1.0475002909073587.
# [I 2025-03-27 23:05:31,422] Trial 30 finished with value: 0.0 and parameters: {'rsi_window': 64, 'rsi_lower': 20, 'rsi_upper': 84, 'stop_loss': 0.052640638342004956, 'take_profit': 0.10380483344941434, 'n_shares': 1000, 'bb_window': 50, 'bb_window_dev': 2, 'ema_window': 36}. Best is trial 21 with value: 1.0475002909073587.
# [I 2025-03-27 23:08:58,250] Trial 31 finished with value: 0.9126951873802667 and parameters: {'rsi_window': 70, 'rsi_lower': 21, 'rsi_upper': 90, 'stop_loss': 0.04034727308983854, 'take_profit': 0.09037202993656612, 'n_shares': 4000, 'bb_window': 80, 'bb_window_dev': 1, 'ema_window': 55}. Best is trial 21 with value: 1.0475002909073587.
# [I 2025-03-27 23:12:13,496] Trial 32 finished with value: 0.0 and parameters: {'rsi_window': 75, 'rsi_lower': 22, 'rsi_upper': 88, 'stop_loss': 0.034706487996645954, 'take_profit': 0.12194737121820029, 'n_shares': 4000, 'bb_window': 86, 'bb_window_dev': 1, 'ema_window': 53}. Best is trial 21 with value: 1.0475002909073587.
# [I 2025-03-27 23:15:14,971] Trial 33 finished with value: 1.8279398647390066 and parameters: {'rsi_window': 57, 'rsi_lower': 19, 'rsi_upper': 89, 'stop_loss': 0.04063819243311198, 'take_profit': 0.08151881655802623, 'n_shares': 4000, 'bb_window': 63, 'bb_window_dev': 1, 'ema_window': 48}. Best is trial 33 with value: 1.8279398647390066.
# [I 2025-03-27 23:18:04,969] Trial 34 finished with value: 1.0422781534324077 and parameters: {'rsi_window': 29, 'rsi_lower': 17, 'rsi_upper': 86, 'stop_loss': 0.0979418858787579, 'take_profit': 0.06582561747958468, 'n_shares': 4000, 'bb_window': 62, 'bb_window_dev': 1, 'ema_window': 48}. Best is trial 33 with value: 1.8279398647390066.
# [I 2025-03-27 23:20:55,317] Trial 35 finished with value: 1.6134532104242207 and parameters: {'rsi_window': 30, 'rsi_lower': 14, 'rsi_upper': 86, 'stop_loss': 0.09523594557114759, 'take_profit': 0.06311711815208616, 'n_shares': 4000, 'bb_window': 53, 'bb_window_dev': 1, 'ema_window': 48}. Best is trial 33 with value: 1.8279398647390066.
# [I 2025-03-27 23:23:45,291] Trial 36 finished with value: 1.0912650167392288 and parameters: {'rsi_window': 28, 'rsi_lower': 14, 'rsi_upper': 86, 'stop_loss': 0.09799665391984311, 'take_profit': 0.06384703577333975, 'n_shares': 4000, 'bb_window': 51, 'bb_window_dev': 1, 'ema_window': 47}. Best is trial 33 with value: 1.8279398647390066.
# [I 2025-03-27 23:26:29,353] Trial 37 finished with value: 0.8033583688503001 and parameters: {'rsi_window': 25, 'rsi_lower': 14, 'rsi_upper': 83, 'stop_loss': 0.09870074127355663, 'take_profit': 0.06139267523812872, 'n_shares': 2000, 'bb_window': 54, 'bb_window_dev': 3, 'ema_window': 43}. Best is trial 33 with value: 1.8279398647390066.
# [I 2025-03-27 23:29:11,763] Trial 38 finished with value: -0.07838987015042538 and parameters: {'rsi_window': 16, 'rsi_lower': 14, 'rsi_upper': 80, 'stop_loss': 0.0889268615675882, 'take_profit': 0.074912293879457, 'n_shares': 4000, 'bb_window': 37, 'bb_window_dev': 1, 'ema_window': 47}. Best is trial 33 with value: 1.8279398647390066.
# [I 2025-03-27 23:32:34,322] Trial 39 finished with value: -0.22963130048532124 and parameters: {'rsi_window': 55, 'rsi_lower': 12, 'rsi_upper': 86, 'stop_loss': 0.08698038939577413, 'take_profit': 0.08128872848949961, 'n_shares': 5000, 'bb_window': 53, 'bb_window_dev': 1, 'ema_window': 41}. Best is trial 33 with value: 1.8279398647390066.
# [I 2025-03-27 23:35:46,431] Trial 40 finished with value: -0.2443899111700568 and parameters: {'rsi_window': 35, 'rsi_lower': 14, 'rsi_upper': 83, 'stop_loss': 0.09453522488816003, 'take_profit': 0.06006375434964559, 'n_shares': 1000, 'bb_window': 29, 'bb_window_dev': 2, 'ema_window': 31}. Best is trial 33 with value: 1.8279398647390066.
# [I 2025-03-27 23:38:34,712] Trial 41 finished with value: 0.8580833083485986 and parameters: {'rsi_window': 28, 'rsi_lower': 17, 'rsi_upper': 86, 'stop_loss': 0.09738358305355205, 'take_profit': 0.06570653561980365, 'n_shares': 4000, 'bb_window': 70, 'bb_window_dev': 1, 'ema_window': 48}. Best is trial 33 with value: 1.8279398647390066.
# [I 2025-03-27 23:41:24,615] Trial 42 finished with value: 1.7437569527142838 and parameters: {'rsi_window': 28, 'rsi_lower': 15, 'rsi_upper': 85, 'stop_loss': 0.08262913866652961, 'take_profit': 0.07157825923922004, 'n_shares': 4000, 'bb_window': 58, 'bb_window_dev': 1, 'ema_window': 48}. Best is trial 33 with value: 1.8279398647390066.
# [I 2025-03-27 23:44:09,057] Trial 43 finished with value: 0.3598610208305985 and parameters: {'rsi_window': 41, 'rsi_lower': 15, 'rsi_upper': 84, 'stop_loss': 0.08442172040771069, 'take_profit': 0.07721633494905156, 'n_shares': 4000, 'bb_window': 42, 'bb_window_dev': 1, 'ema_window': 45}. Best is trial 33 with value: 1.8279398647390066.
# [I 2025-03-27 23:46:52,336] Trial 44 finished with value: 0.757959098863224 and parameters: {'rsi_window': 20, 'rsi_lower': 13, 'rsi_upper': 81, 'stop_loss': 0.09199712711998317, 'take_profit': 0.05688027677823826, 'n_shares': 4000, 'bb_window': 56, 'bb_window_dev': 1, 'ema_window': 39}. Best is trial 33 with value: 1.8279398647390066.
# [I 2025-03-27 23:49:32,947] Trial 45 finished with value: -0.1238250081150674 and parameters: {'rsi_window': 38, 'rsi_lower': 15, 'rsi_upper': 85, 'stop_loss': 0.07679209925863295, 'take_profit': 0.06950050742665714, 'n_shares': 4000, 'bb_window': 75, 'bb_window_dev': 1, 'ema_window': 27}. Best is trial 33 with value: 1.8279398647390066.
# [I 2025-03-27 23:52:16,717] Trial 46 finished with value: -0.16516047998818825 and parameters: {'rsi_window': 47, 'rsi_lower': 16, 'rsi_upper': 73, 'stop_loss': 0.0827289072331005, 'take_profit': 0.09046699017857074, 'n_shares': 4000, 'bb_window': 68, 'bb_window_dev': 3, 'ema_window': 49}. Best is trial 33 with value: 1.8279398647390066.
# [I 2025-03-27 23:55:05,694] Trial 47 finished with value: 0.32972187201731296 and parameters: {'rsi_window': 22, 'rsi_lower': 13, 'rsi_upper': 89, 'stop_loss': 0.09300455944762606, 'take_profit': 0.08856079124103813, 'n_shares': 1000, 'bb_window': 50, 'bb_window_dev': 1, 'ema_window': 46}. Best is trial 33 with value: 1.8279398647390066.
# [I 2025-03-27 23:58:37,992] Trial 48 finished with value: 0.6421538239617713 and parameters: {'rsi_window': 31, 'rsi_lower': 11, 'rsi_upper': 87, 'stop_loss': 0.07167487167058556, 'take_profit': 0.053444757501386865, 'n_shares': 4000, 'bb_window': 55, 'bb_window_dev': 1, 'ema_window': 37}. Best is trial 33 with value: 1.8279398647390066.
# [I 2025-03-28 00:01:23,129] Trial 49 finished with value: 1.35980642878779 and parameters: {'rsi_window': 16, 'rsi_lower': 13, 'rsi_upper': 84, 'stop_loss': 0.07962607088321638, 'take_profit': 0.06893600740980392, 'n_shares': 2000, 'bb_window': 84, 'bb_window_dev': 1, 'ema_window': 43}. Best is trial 33 with value: 1.8279398647390066.

# %%
study.best_value
# Out:
# 1.8279398647390066

# %%
study.best_params
# Out:
# {'rsi_window': 57,
#  'rsi_lower': 19,
#  'rsi_upper': 89,
#  'stop_loss': 0.04063819243311198,
#  'take_profit': 0.08151881655802623,
#  'n_shares': 4000,
#  'bb_window': 63,
#  'bb_window_dev': 1,
#  'ema_window': 48}

# %% [markdown]
# # Optimized Sharpe

# %%
rsi = ta.momentum.RSIIndicator(data.Close, window=57)
bb = ta.volatility.BollingerBands(data.Close, window=63, window_dev=1) 
ema = ta.trend.EMAIndicator(data.Close, window=48)
dataset = data.copy()

dataset["RSI"] = rsi.rsi()
dataset["BB"] = bb.bollinger_mavg()
dataset["EMA"] = ema.ema_indicator()

dataset["RSI_BUY"] = dataset["RSI"] < 19
dataset["RSI_SELL"] = dataset["RSI"] > 89

dataset["BB_BUY"] = bb.bollinger_lband_indicator().astype(bool) # lower band
dataset["BB_SELL"] = bb.bollinger_hband_indicator().astype(bool) # higher band

dataset["EMA_BUY"] = dataset["Close"] > dataset["EMA"]  
dataset["EMA_SELL"] = dataset["Close"] < dataset["EMA"]

dataset = dataset.dropna()

# %%
capital = 1000000
com = 0.125 / 100  # Comisión de compra/venta
n_shares = 4000  # Número de acciones por operación

portfolio_value = [capital]

stop_loss = 0.0406  # Stop Loss del 15%
take_profit = 0.0815  # Take Profit del 8%

win = 0
losses = 0

active_long_positions = None  # Solo una posición activa de cada tipo
active_short_positions = None

for i, row in dataset.iterrows():
    # === Cerrar posiciones largas (Long) ===
    if active_long_positions:
        # Cierre por Stop Loss
        if row.Close < active_long_positions["stop_loss"]:
            pnl = row.Close * n_shares * (1 - com)
            capital += pnl
            active_long_positions = None
            losses += 1

        # Cierre por Take Profit
        elif row.Close > active_long_positions["take_profit"]:
            pnl = row.Close * n_shares * (1 - com)
            capital += pnl
            active_long_positions = None
            win += 1

    # === Cerrar posiciones cortas (Short) ===
    if active_short_positions:
        # Cierre por Stop Loss
        if row.Close > active_short_positions["stop_loss"]:
            pnl = (active_short_positions["opened_at"] - row.Close) * n_shares * (1 - com)
            capital += pnl
            active_short_positions = None
            losses += 1

        # Cierre por Take Profit
        elif row.Close < active_short_positions["take_profit"]:
            pnl = (active_short_positions["opened_at"] - row.Close) * n_shares * (1 - com)
            capital += pnl
            active_short_positions = None
            win += 1

    # === Abrir posiciones largas (Long) ===
    if (row.RSI_BUY + row.BB_BUY + row.EMA_BUY) >= 2 and active_long_positions is None:
        cost = row.Close * n_shares * (1 + com)
        if capital >= cost:  # Solo abrir si hay capital suficiente
            capital -= cost
            active_long_positions = {
                "datetime": row.Datetime,
                "opened_at": row.Close,
                "take_profit": row.Close * (1 + take_profit),
                "stop_loss": row.Close * (1 - stop_loss),
            }

    # === Abrir posiciones cortas (Short) ===
    if (row.RSI_SELL + row.BB_SELL + row.EMA_SELL) >= 2 and active_short_positions is None:
        credit = row.Close * n_shares * (com)
        if capital >= credit:  # Solo abrir si hay capital suficiente
            capital -= credit  
            active_short_positions = {
                "datetime": row.Datetime,
                "opened_at": row.Close,
                "take_profit": row.Close * (1 - take_profit),
                "stop_loss": row.Close * (1 + stop_loss),
            }

    # === Calcular el valor del portafolio ===
    long_value = row.Close * n_shares if active_long_positions else 0
    short_value = (active_short_positions["opened_at"] - row.Close) * n_shares if active_short_positions else 0

    # Agregar el valor total del portafolio
    portfolio_value.append(capital + long_value + short_value)

# %%
fig, ax = plt.subplots(1, 1, figsize=(12,6))

ax.plot(portfolio_value,label = "Porfolio Value")
ax.legend()
ax2 = ax.twinx()
ax2.plot(data.Close, c="C1")
plt.title("Portfolio Value vs Stock Price with an Optimized Sharpe")

plt.show()
